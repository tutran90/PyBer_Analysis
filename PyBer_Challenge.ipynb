# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city           date   fare       ride_id  driver_count   type
# 0  Lake Jonathanshire  1/14/19 10:14  13.83  5.739410e+12             5  Urban
# 1  South Michelleport   3/4/19 18:24  30.24  2.343910e+12            72  Urban
# 2  Port Samanthamouth   2/24/19 4:29  33.44  2.005070e+12            57  Urban
# 3          Rodneyfort  2/10/19 23:22  23.44  5.149250e+12            34  Urban
# 4          South Jack    3/6/19 4:28  34.58  3.908450e+12            46  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
total_rides_each_city = pyber_data_df.groupby(['type']).count()['ride_id']
total_rides_each_city
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
total_drivers = city_data_df.groupby(['type']).sum()['driver_count']
total_drivers
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
total_fares = pyber_data_df.groupby(['type']).sum()['fare']
total_fares
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
#divde the sum of all fares by the total rides 

average_fare_per_ride = total_fares / total_rides_each_city

average_fare_per_ride
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
#divde the sum of all fares by total drivers 

average_fare_per_driver = total_fares / total_drivers

average_fare_per_driver
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 

pyber_data= [total_rides_each_city, total_drivers, total_fares, average_fare_per_ride, average_fare_per_driver]
pyber_summary_df = pd.DataFrame (
                    {"Total Rides": total_rides_each_city,
                    "Total Drivers": total_drivers,
                    "Total Fares": total_fares,
                    "Average Fare Per Ride": average_fare_per_ride,
                    "Average Fare Per Driver": average_fare_per_driver})

pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare Per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare Per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare Per Ride  \
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare Per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  8. Format the columns.
pyber_summary_df.dtypes

pyber_summary_df["Total Rides"] = pyber_summary_df["Total Rides"].map("{:,}".format)
pyber_summary_df["Total Drivers"] = pyber_summary_df["Total Drivers"].map("{:,}".format)
pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("${0:,.2f}".format)
pyber_summary_df["Average Fare Per Ride"] = pyber_summary_df["Average Fare Per Ride"].map("${0:,.2f}".format)
pyber_summary_df["Average Fare Per Driver"] = pyber_summary_df["Average Fare Per Driver"].map("${0:,.2f}".format)

pyber_summary_df
# Out:
#          Total Rides Total Drivers Total Fares Average Fare Per Ride  \
# Rural            125            78   $4,327.93                $34.62
# Suburban         625           490  $19,356.33                $30.97
# Urban          1,625         2,405  $39,854.38                $24.53
#
#          Average Fare Per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df
# Out:
#                     city           date   fare       ride_id  driver_count  \
# 0     Lake Jonathanshire  1/14/19 10:14  13.83  5.739410e+12             5
# 1     South Michelleport   3/4/19 18:24  30.24  2.343910e+12            72
# 2     Port Samanthamouth   2/24/19 4:29  33.44  2.005070e+12            57
# 3             Rodneyfort  2/10/19 23:22  23.44  5.149250e+12            34
# 4             South Jack    3/6/19 4:28  34.58  3.908450e+12            46
# ...                  ...            ...    ...           ...           ...
# 2370         Michaelberg  4/29/19 17:04  13.38  8.550370e+12             6
# 2371     Lake Latoyabury   1/30/19 0:05  20.76  9.018730e+12             2
# 2372         North Jaime  2/10/19 21:03  11.11  2.781340e+12             1
# 2373        West Heather   5/7/19 19:22  44.94  4.256850e+12             4
# 2374          Newtonview  4/25/19 10:20  55.84  9.990580e+12             1
#
#        type
# 0     Urban
# 1     Urban
# 2     Urban
# 3     Urban
# ...

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
pyber_fares_per_city = pyber_data_df.groupby(['type', 'date']).sum()[['fare']]

#using [[]]  will create a date frame, using [] will return a series             
pyber_fares_per_city
# Out:
#                       fare
# type  date
# Rural 1/1/19 9:45    43.69
#       1/11/19 4:39   16.42
#       1/14/19 15:58  54.10
#       1/14/19 7:09   18.05
#       1/15/19 21:44  30.26
# ...                    ...
# Urban 5/8/19 1:54    32.69
#       5/8/19 2:31    41.33
#       5/8/19 4:20    21.99
#       5/8/19 4:39    18.45
#       5/8/19 7:29    18.55
#
# [2364 rows x 1 columns]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
pyber_fares_per_city = pyber_fares_per_city.reset_index()
pyber_fares_per_city
# Out:
#        type           date   fare
# 0     Rural    1/1/19 9:45  43.69
# 1     Rural   1/11/19 4:39  16.42
# 2     Rural  1/14/19 15:58  54.10
# 3     Rural   1/14/19 7:09  18.05
# 4     Rural  1/15/19 21:44  30.26
# ...     ...            ...    ...
# 2359  Urban    5/8/19 1:54  32.69
# 2360  Urban    5/8/19 2:31  41.33
# 2361  Urban    5/8/19 4:20  21.99
# 2362  Urban    5/8/19 4:39  18.45
# 2363  Urban    5/8/19 7:29  18.55
#
# [2364 rows x 3 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 


##ask for help
pyber_fares_per_city = pyber_fares_per_city.pivot(index='date', columns='type', values='fare')

# %%
#Checking the df
pyber_fares_per_city
# Out:
# type          Rural  Suburban  Urban
# date
# 1/1/19 0:08     NaN       NaN  37.91
# 1/1/19 0:46     NaN     47.74    NaN
# 1/1/19 12:32    NaN     25.56    NaN
# 1/1/19 14:40    NaN       NaN   5.42
# 1/1/19 14:42    NaN       NaN  12.31
# ...             ...       ...    ...
# 5/8/19 1:54     NaN       NaN  32.69
# 5/8/19 2:31     NaN       NaN  41.33
# 5/8/19 4:20     NaN       NaN  21.99
# 5/8/19 4:39     NaN       NaN  18.45
# 5/8/19 7:29     NaN       NaN  18.55
#
# [2361 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.


pyber_dates_data_df = pyber_fares_per_city.loc[('1/1/19'):('4/28/19')]

# %%
pyber_dates_data_df.head(10)
# Out:
# type          Rural  Suburban  Urban
# date
# 1/1/19 0:08     NaN       NaN  37.91
# 1/1/19 0:46     NaN     47.74    NaN
# 1/1/19 12:32    NaN     25.56    NaN
# 1/1/19 14:40    NaN       NaN   5.42
# 1/1/19 14:42    NaN       NaN  12.31
# 1/1/19 14:52    NaN     31.15    NaN
# 1/1/19 17:22    NaN       NaN  42.11
# 1/1/19 21:04    NaN       NaN  11.71
# 1/1/19 2:07     NaN     24.07    NaN
# 1/1/19 3:46     NaN       NaN   7.57

# %%
pyber_dates_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2038 entries, 1/1/19 0:08 to 4/27/19 8:48
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     105 non-null    float64
#  1   Suburban  532 non-null    float64
#  2   Urban     1403 non-null   float64
# dtypes: float64(3)
# memory usage: 63.7+ KB

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.

pyber_dates_data_df.index = pd.to_datetime(pyber_dates_data_df.index)

# %%
# 7. Check that the datatype for the index is datetime using df.info()
pyber_dates_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2038 entries, 2019-01-01 00:08:00 to 2019-04-27 08:48:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     105 non-null    float64
#  1   Suburban  532 non-null    float64
#  2   Urban     1403 non-null   float64
# dtypes: float64(3)
# memory usage: 63.7 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
pyber_week_data_summary_df = pyber_dates_data_df.resample('W').sum()

pyber_week_data_summary_df
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  177.65    354.49   613.93
# 2019-04-14  214.60    568.47  2024.25
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1169.04  1909.51

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
#Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.

style.use('fivethirtyeight')


fig = pyber_week_data_summary_df.plot(figsize=(50,10))
#x_axis = np.arrange(len(pyber_week_data_summary_df))

fig.set_title("Total Fare By City")
fig.set_ylabel(f"Fare(USD$)")
fig.set_xlabel("Month")

plt.show()
#ax.set_ylim(0,2500,step=500)

#fig.set_ylim(0,2500,step=500)

#fig, ax.subplot()
#pyber_week_data_summary_df.plot(x=x_axis,y="fare", label='city')


#ax.legend()
#ax.grid()
plt.savefig("Total_Fare_By_City_Type.png")

# %%
type(fig)
